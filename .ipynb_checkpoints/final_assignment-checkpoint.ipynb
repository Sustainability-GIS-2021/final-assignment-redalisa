# %% [markdown]
# # Final assignment
#
# ## Instructions
#
# - Read the instructions for the final assignment from the [course page](https://sustainability-gis.readthedocs.io/en/latest/lessons/final-assignment/final-assignment.html).
# - To get help with Markdown formatting check [this page](https://www.markdownguide.org/cheat-sheet/).
# - If you don't know how to add a Markdown cell check [this page](https://www.datacamp.com/community/tutorials/markdown-in-jupyter-notebook)

# %% [markdown]
# ## Add your work below
#
# Mix markdown cells with code cells regularly to explain and document your work / codes (in a similar manner as how the Exercises of this course were written).
# Below we provide you a suggestion for the structure of the report by listing the main components that would be good to include in your work. However, you do not necessarily need to follow this structure and you can adjust the headings as you see best.

# %% [markdown]
# ## 1. Introduction
#
# "The global attention to transport has continued in recent years. World leaders recognized unanimously at the 2012 United Nations Conference on Sustainable Development (Rio +20) that transportation and mobility are central to sustainable development. Sustainable transportation can enhance economic growth and improve accessibility. Sustainable transport achieves better integration of the economy while respecting the environment. improving social equity, health, resilience of cities, urban-rural linkages and productivity of rural areas"
#
# My two focus cities: Memphis, TN and Austin, TX
# Comparing the cities on three indicators from SDG target 11.2:
# - Road traffic deaths per 100,000 population
#  Preliminary research:
#  Memphis: 250 deaths in 2020 / 651,932 total population = 38 deaths per 100,000
#  Austin: 74 deaths in 2018 / 935,755 total population = 7.9 deaths per 100,000
# - Access to all-weather road (% access within [x] km distance to road)
# - Percentage of people within 0.5km of public transit running at least every 20 minutes.

# %% [markdown]
# ## 2. Data and methods
#
# Describe your data (list also the used data sources) and give an overview of the methods that you use in your work.
#
# Data sources for Crash Reports:
# data.austintexas.gov
# TN Department of Safety & Homeland Security
# Data sources for Public Transit:
# General Transit Feed Specification data (GTFS) fetched from transitland

# %%
# Data processing, does not need to be run as the data has already been unzipped 
import zipfile
with zipfile.ZipFile("Memphis_TN_transitfeed2.zip","r") as zip_ref:
    zip_ref.extractall("Memphis_TN_transitfeed")

# %%
import pandas as pd
df = pd.read_csv('data/Memphis_TN_transitfeed/stops.txt', delimiter = ",")
df
# Out:
#       stop_id stop_code             stop_name                   stop_desc  \
# 0           6  YALCOVWM   YALE@COVINGTON PIKE     YALE RD & CONNECTING RD
# 1           7  AIRKETSN  AIRWAYS BLVD@KETCHUM   AIRWAYS BLVD & KETCHUM RD
# 2          10  CLEMA1SN     CLEVELAND@MADISON  N CLEVELAND ST & COURT AVE
# 3          15  FOUGEOSF   4TH ST@ GEORGIA AVE    S 4TH ST & E GEORGIA AVE
# 4          24  FROGEPNN       CENTRAL STATION  S FRONT ST & E CALHOUN AVE
# ...       ...       ...                   ...                         ...
# 3503     7096  THIWEANF          THIRD@WEAVER       0 S 3RD ST & DRIVEWAY
# 3504     7097  THIDELNN           THIRD@DELTA       0 S 3RD ST & DELTA RD
# 3505     7098  THISHENF          THIRD@SHELBY           0 S 3RD ST & RAMP
# 3506     7099  THIFORNM            THIRD@FORD    0 S 3RD ST & WESTVIEW RD
# 3507     7100  THIWESNF    THIRD@WESTERN PARK       0 S 3RD ST & DRIVEWAY
#
#        stop_lat   stop_lon  zone_id  stop_url  location_type  parent_station  \
# 0     35.221558 -89.897067      NaN       NaN            NaN             NaN
# 1     35.079543 -89.984917      NaN       NaN            NaN             NaN
# 2     35.139020 -90.016438      NaN       NaN            NaN             NaN
# 3     35.128896 -90.050605      NaN       NaN            NaN             NaN
# 4     35.132731 -90.060719      NaN       NaN            NaN             NaN
# ...         ...        ...      ...       ...            ...             ...
# 3503  35.012262 -90.096245      NaN       NaN            NaN             NaN
# 3504  35.019798 -90.088678      NaN       NaN            NaN             NaN
# 3505  35.021479 -90.087010      NaN       NaN            NaN             NaN
# 3506  35.025341 -90.083154      NaN       NaN            NaN             NaN
# 3507  35.032098 -90.076381      NaN       NaN            NaN             NaN
#
#       stop_timezone  wheelchair_boarding
# 0               NaN                    0
# 1               NaN                    0
# 2               NaN                    0
# 3               NaN                    0
# 4               NaN                    0
# ...             ...                  ...
# 3503            NaN                    0
# 3504            NaN                    0
# 3505            NaN                    0
# 3506            NaN                    0
# 3507            NaN                    0
#
# [3508 rows x 12 columns]

# %%
import geopandas as gpd
from shapely.geometry import Point, LineString

# creating a geometry column 
geometry = [Point(xy) for xy in zip(df['stop_lon'], df['stop_lat'])]
# Coordinate reference system : WGS84
crs = {'init': 'epsg:4326'}
# Creating a Geographic data frame 
stops= gpd.GeoDataFrame(df, crs=crs, geometry=geometry)
stops.head()
# Out:
# /opt/conda/lib/python3.8/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
#    stop_id stop_code             stop_name                   stop_desc  \
# 0        6  YALCOVWM   YALE@COVINGTON PIKE     YALE RD & CONNECTING RD
# 1        7  AIRKETSN  AIRWAYS BLVD@KETCHUM   AIRWAYS BLVD & KETCHUM RD
# 2       10  CLEMA1SN     CLEVELAND@MADISON  N CLEVELAND ST & COURT AVE
# 3       15  FOUGEOSF   4TH ST@ GEORGIA AVE    S 4TH ST & E GEORGIA AVE
# 4       24  FROGEPNN       CENTRAL STATION  S FRONT ST & E CALHOUN AVE
#
#     stop_lat   stop_lon  zone_id  stop_url  location_type  parent_station  \
# 0  35.221558 -89.897067      NaN       NaN            NaN             NaN
# 1  35.079543 -89.984917      NaN       NaN            NaN             NaN
# 2  35.139020 -90.016438      NaN       NaN            NaN             NaN
# 3  35.128896 -90.050605      NaN       NaN            NaN             NaN
# 4  35.132731 -90.060719      NaN       NaN            NaN             NaN
#
#    stop_timezone  wheelchair_boarding                    geometry
# 0            NaN                    0  POINT (-89.89707 35.22156)
# 1            NaN                    0  POINT (-89.98492 35.07954)
# 2            NaN                    0  POINT (-90.01644 35.13902)
# 3            NaN                    0  POINT (-90.05061 35.12890)
# 4            NaN                    0  POINT (-90.06072 35.13273)

# %%
stops["stop_name"].nunique()
# Out:
# 2680

# %%
stops.plot(figsize = (12, 12))
# Out:
# <AxesSubplot:>

# %%
shapes = pd.read_csv('data/Memphis_TN_transitfeed/shapes.txt', delimiter = ",")
shapes.head()
# Out:
#    shape_id  shape_pt_lat  shape_pt_lon  shape_pt_sequence  \
# 0     37056     35.076276    -89.932316                  1
# 1     37056     35.076249    -89.932261                  2
# 2     37056     35.076133    -89.932261                  3
# 3     37056     35.076008    -89.932272                  4
# 4     37056     35.075945    -89.932284                  5
#
#    shape_dist_traveled
# 0               0.0000
# 1               0.0058
# 2               0.0188
# 3               0.0329
# 4               0.0399

# %%
# creating a geometry column 
geometry = [Point(xy) for xy in zip(shapes['shape_pt_lon'], shapes['shape_pt_lat'])]
# Coordinate reference system : WGS84
crs = {'init': 'epsg:4326'}
# Creating a Geographic data frame 
shapes_gdf = gpd.GeoDataFrame(shapes, crs=crs, geometry=geometry)
shapes_gdf.head()
# Out:
# /opt/conda/lib/python3.8/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
#    shape_id  shape_pt_lat  shape_pt_lon  shape_pt_sequence  \
# 0     37056     35.076276    -89.932316                  1
# 1     37056     35.076249    -89.932261                  2
# 2     37056     35.076133    -89.932261                  3
# 3     37056     35.076008    -89.932272                  4
# 4     37056     35.075945    -89.932284                  5
#
#    shape_dist_traveled                    geometry
# 0               0.0000  POINT (-89.93232 35.07628)
# 1               0.0058  POINT (-89.93226 35.07625)
# 2               0.0188  POINT (-89.93226 35.07613)
# 3               0.0329  POINT (-89.93227 35.07601)
# 4               0.0399  POINT (-89.93228 35.07594)

# %%
# group by shape_id then transform into linestrings
grouped = shapes_gdf.groupby("shape_id")['geometry'].apply(lambda x: LineString(x.tolist()))
grouped
# Out:
# shape_id
# 37056    LINESTRING (-89.93232 35.07628, -89.93226 35.0...
# 37058    LINESTRING (-89.93612 35.00164, -89.93679 35.0...
# 37059    LINESTRING (-90.04781 35.15658, -90.04762 35.1...
# 37061    LINESTRING (-89.94015 35.17624, -89.93990 35.1...
# 37064    LINESTRING (-90.05896 35.13409, -90.05894 35.1...
#                                ...
# 37256    LINESTRING (-90.01904 35.15837, -90.01903 35.1...
# 37258    LINESTRING (-89.93232 35.07628, -89.93226 35.0...
# 37259    LINESTRING (-89.91099 35.22175, -89.91001 35.2...
# 37354    LINESTRING (-90.04781 35.15658, -90.04762 35.1...
# 37355    LINESTRING (-89.91001 35.22174, -89.90938 35.2...
# Name: geometry, Length: 81, dtype: geometry

# %%
# Transform GeoSeries into GeoDataFrame
routes = gpd.GeoDataFrame(grouped)
# Reset index to access the ID number column of the routes
routes = routes.reset_index()
# Rename column to make it more intuitive for the reader
routes = routes.rename(columns = {"shape_id":"route_id"})
# View the dataframe
routes
# Out:
#     route_id                                           geometry
# 0      37056  LINESTRING (-89.93232 35.07628, -89.93226 35.0...
# 1      37058  LINESTRING (-89.93612 35.00164, -89.93679 35.0...
# 2      37059  LINESTRING (-90.04781 35.15658, -90.04762 35.1...
# 3      37061  LINESTRING (-89.94015 35.17624, -89.93990 35.1...
# 4      37064  LINESTRING (-90.05896 35.13409, -90.05894 35.1...
# ..       ...                                                ...
# 76     37256  LINESTRING (-90.01904 35.15837, -90.01903 35.1...
# 77     37258  LINESTRING (-89.93232 35.07628, -89.93226 35.0...
# 78     37259  LINESTRING (-89.91099 35.22175, -89.91001 35.2...
# 79     37354  LINESTRING (-90.04781 35.15658, -90.04762 35.1...
# 80     37355  LINESTRING (-89.91001 35.22174, -89.90938 35.2...
#
# [81 rows x 2 columns]

# %%
# Preview the data
routes.plot(figsize=(12,12))
# Out:
# <AxesSubplot:>

# %%
# Memphis zip code population data source: US Census 2010
mem_postal = pd.read_csv("data/popzipcode_memphis.csv", delimiter = ",", dtype={'Population': int })
mem_postal.head()
# Out:
#     #  Zip Code               Location                City  Population  \
# 0  23     38103  35.184023, -90.077284  Memphis, Tennessee        7675
# 1   2     38104  35.132422, -90.004640  Memphis, Tennessee       24727
# 2   1     38105  35.150642, -90.033969  Memphis, Tennessee        8976
# 3  22     38106  35.104113, -90.090113  Memphis, Tennessee       33784
# 4   8     38107  35.170636, -90.022027  Memphis, Tennessee       22109
#
#   People / Sq. Mile National Rank
# 0          1,023.74        #6,268
# 1          5,030.99        #1,701
# 2          5,247.84        #1,606
# 3          1,247.46        #5,763
# 4          3,915.78        #2,385

# %%
census_tract = pd.read_csv("data/DECENNIALSF12010.P1_data_with_overlays_2021-03-10T031806.csv", delimiter = ",")
census_tract.drop([0], axis=0, inplace = True)
census_tract.head()
# Out:
#                  GEO_ID                                           NAME P001001
# 1  1400000US47157007821   Census Tract 78.21, Shelby County, Tennessee    5903
# 2  1400000US47157022022  Census Tract 220.22, Shelby County, Tennessee    3377
# 3  1400000US47157022112  Census Tract 221.12, Shelby County, Tennessee    6014
# 4  1400000US47157022121  Census Tract 221.21, Shelby County, Tennessee    4436
# 5  1400000US47157005500      Census Tract 55, Shelby County, Tennessee    2731

# %%
import re
l = []
for i in census_tract['NAME']:
    x = re.findall(r'\d+\.*\d*', i)
    l.append(x)
       
tract_num = []
for sublist in l:
    for item in sublist:
        tract_num.append(item)
        
census_tract['tract_num'] = tract_num
census_tract
# Out:
#                    GEO_ID                                           NAME  \
# 1    1400000US47157007821   Census Tract 78.21, Shelby County, Tennessee
# 2    1400000US47157022022  Census Tract 220.22, Shelby County, Tennessee
# 3    1400000US47157022112  Census Tract 221.12, Shelby County, Tennessee
# 4    1400000US47157022121  Census Tract 221.21, Shelby County, Tennessee
# 5    1400000US47157005500      Census Tract 55, Shelby County, Tennessee
# ..                    ...                                            ...
# 217  1400000US47157020400     Census Tract 204, Shelby County, Tennessee
# 218  1400000US47157020531  Census Tract 205.31, Shelby County, Tennessee
# 219  1400000US47157020210  Census Tract 202.10, Shelby County, Tennessee
# 220  1400000US47157020300     Census Tract 203, Shelby County, Tennessee
# 221  1400000US47157020523  Census Tract 205.23, Shelby County, Tennessee
#
#     P001001 tract_num
# 1      5903     78.21
# 2      3377    220.22
# 3      6014    221.12
# 4      4436    221.21
# 5      2731        55
# ..      ...       ...
# 217    1118       204
# 218    5803    205.31
# 219    6292    202.10
# 220    5393       203
# 221    3547    205.23
#
# [221 rows x 4 columns]

# %%
s = []
for i in census_tract['GEO_ID']:
    for t in i.split():
        x = t.replace('1400000US', '')
        s.append(x)
        
census_tract['GEOID10'] = s
census_tract.head()
# Out:
#                  GEO_ID                                           NAME  \
# 1  1400000US47157007821   Census Tract 78.21, Shelby County, Tennessee
# 2  1400000US47157022022  Census Tract 220.22, Shelby County, Tennessee
# 3  1400000US47157022112  Census Tract 221.12, Shelby County, Tennessee
# 4  1400000US47157022121  Census Tract 221.21, Shelby County, Tennessee
# 5  1400000US47157005500      Census Tract 55, Shelby County, Tennessee
#
#   P001001 tract_num      GEOID10
# 1    5903     78.21  47157007821
# 2    3377    220.22  47157022022
# 3    6014    221.12  47157022112
# 4    4436    221.21  47157022121
# 5    2731        55  47157005500

# %%
# Downloaded from US Census database 2010
tracts = gpd.read_file('data/tl_2020_47157_tract10.shp')
tracts
# Out:
#     STATEFP10 COUNTYFP10 TRACTCE10      GEOID10 NAME10    NAMELSAD10 MTFCC10  \
# 0          47        157    000100  47157000100      1  Census Tract   G5020
# 1          47        157    000200  47157000200      2  Census Tract   G5020
# 2          47        157    000300  47157000300      3  Census Tract   G5020
# 3          47        157    000400  47157000400      4  Census Tract   G5020
# 4          47        157    000600  47157000600      6  Census Tract   G5020
# ..        ...        ...       ...          ...    ...           ...     ...
# 216        47        157    022700  47157022700    227  Census Tract   G5020
# 217        47        157    980100  47157980100   9801  Census Tract   G5020
# 218        47        157    980200  47157980200   9802  Census Tract   G5020
# 219        47        157    980300  47157980300   9803  Census Tract   G5020
# 220        47        157    980400  47157980400   9804  Census Tract   G5020
#
#     FUNCSTAT10   ALAND10  AWATER10   INTPTLAT10    INTPTLON10  \
# 0            S   4186008   2549731  +35.1745847  -090.0518440
# 1            S   1056567     45527  +35.1681487  -090.0424321
# 2            S   2872435      8845  +35.1768246  -090.0293407
# 3            S   2276724     91258  +35.1768576  -090.0145439
# 4            S   3883873   1208912  +35.1837381  -089.9990705
# ..         ...       ...       ...          ...           ...
# 216          S   8268052     32655  +35.0080388  -090.0514313
# 217          S  19126877         0  +35.0533955  -089.9712441
# 218          S  41222220   4249312  +35.1037821  -090.1408240
# 219          S  96330852   5938582  +35.0251440  -090.1954899
# 220          S  18232658         0  +35.1360475  -089.8330386
#
#                                               geometry
# 0    POLYGON ((-90.06468 35.17020, -90.06467 35.171...
# 1    POLYGON ((-90.04925 35.16428, -90.04910 35.165...
# 2    POLYGON ((-90.03673 35.16405, -90.03640 35.166...
# 3    POLYGON ((-90.02512 35.16874, -90.02509 35.169...
# 4    POLYGON ((-90.00847 35.17278, -90.00846 35.172...
# ..                                                 ...
# 216  POLYGON ((-90.06911 35.00237, -90.06909 35.002...
# 217  POLYGON ((-89.99149 35.05872, -89.99148 35.059...
# 218  POLYGON ((-90.18863 35.07573, -90.18206 35.089...
# 219  POLYGON ((-90.31030 35.00429, -90.31009 35.006...
# 220  POLYGON ((-89.87853 35.15042, -89.87842 35.150...
#
# [221 rows x 13 columns]

# %%
merged = pd.merge(census_tract, tracts, on = "GEOID10")
merged
# Out:
#                    GEO_ID                                           NAME  \
# 0    1400000US47157007821   Census Tract 78.21, Shelby County, Tennessee
# 1    1400000US47157022022  Census Tract 220.22, Shelby County, Tennessee
# 2    1400000US47157022112  Census Tract 221.12, Shelby County, Tennessee
# 3    1400000US47157022121  Census Tract 221.21, Shelby County, Tennessee
# 4    1400000US47157005500      Census Tract 55, Shelby County, Tennessee
# ..                    ...                                            ...
# 216  1400000US47157020400     Census Tract 204, Shelby County, Tennessee
# 217  1400000US47157020531  Census Tract 205.31, Shelby County, Tennessee
# 218  1400000US47157020210  Census Tract 202.10, Shelby County, Tennessee
# 219  1400000US47157020300     Census Tract 203, Shelby County, Tennessee
# 220  1400000US47157020523  Census Tract 205.23, Shelby County, Tennessee
#
#     P001001 tract_num      GEOID10 STATEFP10 COUNTYFP10 TRACTCE10  NAME10  \
# 0      5903     78.21  47157007821        47        157    007821   78.21
# 1      3377    220.22  47157022022        47        157    022022  220.22
# 2      6014    221.12  47157022112        47        157    022112  221.12
# 3      4436    221.21  47157022121        47        157    022121  221.21
# 4      2731        55  47157005500        47        157    005500      55
# ..      ...       ...          ...       ...        ...       ...     ...
# 216    1118       204  47157020400        47        157    020400     204
# 217    5803    205.31  47157020531        47        157    020531  205.31
# 218    6292    202.10  47157020210        47        157    020210  202.10
# 219    5393       203  47157020300        47        157    020300     203
# 220    3547    205.23  47157020523        47        157    020523  205.23
#
#        NAMELSAD10 MTFCC10 FUNCSTAT10   ALAND10  AWATER10   INTPTLAT10  \
# 0    Census Tract   G5020          S   3493025         0  +35.0798930
# 1    Census Tract   G5020          S   4921437         0  +35.0498914
# 2    Census Tract   G5020          S   3293232         0  +35.0282414
# 3    Census Tract   G5020          S   4373318         0  +35.0137999
# 4    Census Tract   G5020          S   3355152         0  +35.0939257
# ..            ...     ...        ...       ...       ...          ...
# 216  Census Tract   G5020          S  13197547     40648  +35.3569290
# 217  Census Tract   G5020          S  17558802     51830  +35.2551486
# 218  Census Tract   G5020          S  58256042    264330  +35.3718942
# 219  Census Tract   G5020          S  15413690         0  +35.3332303
# 220  Census Tract   G5020          S   2501636         0  +35.2457594
#
#        INTPTLON10                                           geometry
# 0    -090.0072307  POLYGON ((-90.02114 35.07144, -90.02111 35.071...
# 1    -090.0005466  POLYGON ((-90.01935 35.06133, -90.01756 35.061...
# 2    -090.0009887  POLYGON ((-90.01257 35.02328, -90.01256 35.023...
# 3    -090.0225038  POLYGON ((-90.03890 35.02098, -90.03869 35.020...
# 4    -090.0593626  POLYGON ((-90.06751 35.09333, -90.06750 35.093...
# ..            ...                                                ...
# 216  -089.8657447  POLYGON ((-89.89111 35.34364, -89.89032 35.344...
# 217  -089.9027386  POLYGON ((-89.92994 35.25379, -89.92991 35.254...
# 218  -089.8731724  POLYGON ((-89.95526 35.39358, -89.95390 35.393...
# 219  -089.8953467  POLYGON ((-89.92642 35.32631, -89.92568 35.327...
# 220  -089.9346120  POLYGON ((-89.94614 35.24370, -89.94590 35.244...
#
# [221 rows x 17 columns]

# %%
merged['P001001'] = merged['P001001'].astype('int64')

# %%
# Creating a Geographic data frame 
mem_census = gpd.GeoDataFrame(merged, crs = {'init': 'epsg:4326'}, geometry=merged['geometry'])
mem_census.head()
# Out:
# /opt/conda/lib/python3.8/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))
#                  GEO_ID                                           NAME  \
# 0  1400000US47157007821   Census Tract 78.21, Shelby County, Tennessee
# 1  1400000US47157022022  Census Tract 220.22, Shelby County, Tennessee
# 2  1400000US47157022112  Census Tract 221.12, Shelby County, Tennessee
# 3  1400000US47157022121  Census Tract 221.21, Shelby County, Tennessee
# 4  1400000US47157005500      Census Tract 55, Shelby County, Tennessee
#
#    P001001 tract_num      GEOID10 STATEFP10 COUNTYFP10 TRACTCE10  NAME10  \
# 0     5903     78.21  47157007821        47        157    007821   78.21
# 1     3377    220.22  47157022022        47        157    022022  220.22
# 2     6014    221.12  47157022112        47        157    022112  221.12
# 3     4436    221.21  47157022121        47        157    022121  221.21
# 4     2731        55  47157005500        47        157    005500      55
#
#      NAMELSAD10 MTFCC10 FUNCSTAT10  ALAND10  AWATER10   INTPTLAT10  \
# 0  Census Tract   G5020          S  3493025         0  +35.0798930
# 1  Census Tract   G5020          S  4921437         0  +35.0498914
# 2  Census Tract   G5020          S  3293232         0  +35.0282414
# 3  Census Tract   G5020          S  4373318         0  +35.0137999
# 4  Census Tract   G5020          S  3355152         0  +35.0939257
#
#      INTPTLON10                                           geometry
# 0  -090.0072307  POLYGON ((-90.02114 35.07144, -90.02111 35.071...
# 1  -090.0005466  POLYGON ((-90.01935 35.06133, -90.01756 35.061...
# 2  -090.0009887  POLYGON ((-90.01257 35.02328, -90.01256 35.023...
# 3  -090.0225038  POLYGON ((-90.03890 35.02098, -90.03869 35.020...
# 4  -090.0593626  POLYGON ((-90.06751 35.09333, -90.06750 35.093...

# %%
ax = mem_census.plot('P001001', figsize = (10,10), legend = True)
#routes.plot(ax = ax, color = 'red')
#stops.plot(ax = ax, color = 'k')

# %% [markdown]
# ## 3. Data analysis + Results
#
# Add and explain your analysis workflow below here.

# %%
import pandas as pd
from pyrosm import OSM, get_data

# We fetch data for Memphis from OSM
osm = OSM(get_data("memphis"))

# Parse roads that can be driven by car
roads = osm.get_network(network_type="driving")
# Out:
# Downloaded Protobuf data 'Memphis.osm.pbf' (16.68 MB) to:
# '/tmp/pyrosm/Memphis.osm.pbf'

# %%
roads.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# View the unique road labels 
roads["highway"].unique()
# Out:
# array(['residential', 'service', 'tertiary', 'unclassified', 'primary',
#        'tertiary_link', 'secondary_link', 'motorway_link', 'secondary',
#        'primary_link', 'motorway', 'trunk_link', 'trunk', 'living_street',
#        'rest_area', 'residential_link'], dtype=object)

# %%
roads.head()
# Out:
#   access  area bicycle bridge cycleway  foot      highway junction lanes  \
# 0   None  None    None   None     None  None  residential     None  None
# 1   None  None    None   None     None  None  residential     None  None
# 2   None  None    None   None     None  None      service     None  None
# 3   None  None    None   None     None  None  residential     None  None
# 4   None  None    None   None     None  None     tertiary     None  None
#
#     lit  ... surface tunnel  turn        id timestamp version  \
# 0  None  ...    None   None  None  12772799         0      -1
# 1  None  ...    None   None  None  12772805         0      -1
# 2  None  ...    None   None  None  12772806         0      -1
# 3  None  ...    None   None  None  12772812         0      -1
# 4  None  ...    None   None  None  12772821         0      -1
#
#                                                 tags osm_type  \
# 0  {"tiger:cfcc":"A41","tiger:county":"Crittenden...      way
# 1  {"source:geometry":"https://gis.arkansas.gov/"...      way
# 2  {"tiger:cfcc":"A41","tiger:county":"Crittenden...      way
# 3  {"tiger:cfcc":"A41","tiger:county":"Crittenden...      way
# 4  {"tiger:cfcc":"A41","tiger:county":"Crittenden...      way
#
#                                             geometry  length
# 0  MULTILINESTRING ((-90.19383 35.21924, -90.1938...  2611.0
# 1  MULTILINESTRING ((-90.35716 35.00212, -90.3573...   237.0
# 2  MULTILINESTRING ((-90.35716 35.00212, -90.3564...  3344.0
# 3  MULTILINESTRING ((-90.18696 35.19314, -90.1870...   279.0
# 4  MULTILINESTRING ((-90.19343 35.16968, -90.1934...   558.0
#
# [5 rows x 27 columns]

# %%
# Parse nodes and edges
# Uses osm instance defined previously
nodes, edges = osm.get_network(network_type="driving", nodes=True)

# %%
# Count values of the edges' speed limits, including all NaN values
edges["maxspeed"].value_counts(dropna=False)
# Out:
# NaN       552827
# 45 mph      4714
# 40 mph      4114
# 55 mph      2546
# 65 mph      1918
# 35 mph      1471
# 30 mph       594
# 50 mph       555
# 70 mph       459
# 15 mph       322
# 20 mph       305
# 19 mph       138
# 25 mph        61
# 17 mph        57
# 10 mph        39
# 80            30
# 45            25
# 70            18
# 30            11
# 18 mph         2
# 5 mph          1
# 35             1
# Name: maxspeed, dtype: int64

# %%
ax = roads.plot(figsize = (12,12))
stops.plot(ax = ax, color = 'red')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Create a 0.5 km buffer around each bus stops in order to assess percentage of population with access to the stop

# %%
for idx, row in stops.iterrows():
    
    # Find the closest nodes for origin
    orig_node_id = ox.get_nearest_node(G, point=(row['geometry'].y, row['geometry'].x), method='haversine')
    # Create the 10 min (600 sec) catchment area around each hospital 
    sub_graph = nx.ego_graph(G, n=orig_node_id, radius=600, distance = 'travel_time_seconds')

# %%
## Austin crash fatality data

import requests 
r = requests.get('https://www.austintexas.gov/police/reports/advance_search.cfm')

# %%
print(r.url)
# Out:
# https://www.austintexas.gov/police/reports/advance_search.cfm

# %%
r.encoding
# Out:
# 'UTF-8'

# %%
payload = {'startdate': '01%2F07%2F2020', 'numdays': ['6']}
r = requests.get('https://www.austintexas.gov/police/reports/advance_search.cfm')
print(r.url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e8866af62e38> in <module>
#       1 payload = {'startdate': '01%2F07%2F2020', 'numdays': ['6']}
# ----> 2 r = requests.get('https://www.austintexas.gov/police/reports/advance_search.cfm')
#       3 print(r.url)
#
# NameError: name 'requests' is not defined

# %% [markdown]
# ## 4. Discussion
#
# Add discussion here.

# %% [markdown]
# ## 5. References
#
# TN Department of Safety and Homeland Security
# https://www.tn.gov/content/dam/tn/safety/documents/dailyfatalitybycounty2020.pdf
# Austin TX Traffic Fatalities
# https://www.austintexas.gov/department/traffic-fatalities
